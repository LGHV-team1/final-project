# %% [markdown]
# # 수행한 것
# - 제목만 전처리

# %% [markdown]
# ## 데이터로드

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# plotting 환경 설정
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
plt.rcParams['figure.figsize'] = (5,5) # 그래프 크기
plt.rcParams['font.family'] = 'Malgun Gothic' # 글꼴
plt.rcParams['font.size'] = 12 # 글꼴 크기
plt.rcParams['axes.unicode_minus'] = False # 마이너스 표기

# 그래프가 노트북 안에 보이게 하기 위해
# %matplotlib inline

# %%
# 데이터를 구분하는 문자를 지정하는 옵션
con8 = pd.read_csv('../data/데이터스쿨3차_2308월/데이터스쿨_3차_콘텐츠_2308.csv', encoding = 'cp949', sep = '\t')
con9 = pd.read_csv('../data/데이터스쿨3차_2309월/데이터스쿨_3차_콘텐츠_2309.csv', encoding = 'cp949', sep = '\t')

# %%
c8 = con8.copy()
c9 = con9.copy()

# %% [markdown]
# ## content 전처리

# %%
# con 데이터프레임을 header가 같은 열을 기준으로 합치기
con89 = pd.concat([con8, con9], ignore_index=True)
con89.head()
# Out:
#       subsr           series_nm          super_asset_nm ct_cl genre_of_ct_cl  \
# 0  65968000     (영어더빙)핑크퐁 동물 동요           핑크퐁 동물 동요 20회    키즈             기타
# 1  65968000     (영어더빙)핑크퐁 동물 동요           핑크퐁 동물 동요 20회    키즈             기타
# 2  66056000  라바 키즈동요(한국어) Part4  라바 키즈동요(한국어) Part4 17회    키즈             기타
# 3  66056000  라바 키즈동요(한국어) Part4  라바 키즈동요(한국어) Part4 17회    키즈             기타
# 4  63086000       지니강이 플러스 시즌7.       지니강이 플러스 시즌7. 26회    키즈             기타
#
#                                                 SMRY  ACTR_DISP disp_rtm  \
# 0  겨울잠. 숲, 바다, 극지방 등 세계 여러 곳에 사는 동물 친구들을 만나러 가자! ...        핑크퐁     0:01
# 1  겨울잠. 숲, 바다, 극지방 등 세계 여러 곳에 사는 동물 친구들을 만나러 가자! ...        핑크퐁     0:01
# 2  징글벨 크리스마스. 안녕하신가 친구들! 메리 크리스마스~ 징글벨 크리스마스 징글벨 ...     엘로우,레드     0:02
# 3  징글벨 크리스마스. 안녕하신가 친구들! 메리 크리스마스~ 징글벨 크리스마스 징글벨 ...     엘로우,레드     0:02
# 4  로봇 세상에서 킥보드를 타요. 로보카 폴리 브룸스 타운에서 킥보드를 타요~ / 새로...  헤이지니,럭키강이     0:11
#
#            log_dt
# 0  20230813071155
# 1  20230813071215
# 2  20230808085440
# 3  20230808085432
# 4  20230827145542

# %%
from pandas._libs.tslibs.offsets import Hour
import re
def preprocessing_con(df):
  # 특수문자 정리
  ## 예고편 제거
  df = df[~df['super_asset_nm'].str.contains(r'\(예고편\)|\(예고\)', regex=True)]

  # series_nm 괄호와 그 안의 내용 제거
  df['series_nm'] = df['series_nm'].str.replace(r'\([^()]*\)', '', regex=True)
  df['series_nm'] = df['series_nm'].str.replace(r'\[[^\[\]]*\]', '', regex=True)
  df['series_nm'] = df['series_nm'].str.replace(r'\.\.\.', '', regex=True)
  df['series_nm'] = df['series_nm'].str.replace(r'…', '', regex=True)
  df['series_nm'] = df['series_nm'].str.replace('-', ' ')
  df['series_nm'] = df['series_nm'].str.rstrip('.')

  # super_asset_nm 변경
  df['super_asset_nm'] = df['super_asset_nm'].str.replace(r'\([^()]*\)', '', regex=True)
  df['super_asset_nm'] = df['super_asset_nm'].str.replace(r'\[[^\[\]]*\]', '', regex=True)
  df['super_asset_nm'] = df['super_asset_nm'].str.replace(r'\.\.\.', '', regex=True)
  df['super_asset_nm'] = df['super_asset_nm'].str.replace(r'…', '', regex=True)
  df['super_asset_nm'] = df['super_asset_nm'].str.replace('-', ' ')
  df['super_asset_nm'] = df['super_asset_nm'].str.rstrip('.')

  # 회, 회. 제거
  df['series_nm'] = df['series_nm'].str.replace(r'무삭제판|무삭제', '', regex = True)
  df['series_nm'] = df['series_nm'].str.replace(r'실사판', '', regex = True)
  df['series_nm'] = df['series_nm'].str.replace(r'\d+회$', '', regex=True)
  df['series_nm'] = df['series_nm'].str.replace(r'\d+회\.', '', regex=True)
  df['series_nm'] = df['series_nm'].str.replace(r'\d+화$', '', regex = True)
  df['series_nm'] = df['series_nm'].str.strip()
  df['series_nm'] = df['series_nm'].str.rstrip('.')

  df['super_asset_nm'] = df['super_asset_nm'].str.replace(r'무삭제판|무삭제', '', regex = True)
  df['super_asset_nm'] = df['super_asset_nm'].str.replace(r'실사판', '', regex = True)
  df['super_asset_nm'] = df['super_asset_nm'].str.replace(r'\d+회$', '', regex=True)
  df['super_asset_nm'] = df['super_asset_nm'].str.replace(r'\d+회\.', '', regex=True)
  df['super_asset_nm'] = df['super_asset_nm'].str.replace(r'\d+화$', '', regex = True)
  df['super_asset_nm'] = df['super_asset_nm'].str.strip()
  df['super_asset_nm'] = df['super_asset_nm'].str.rstrip('.')

  # 'series_nm'이 null인 경우, 'super_asset_nm'의 값으로 대체
  df['series_nm'].fillna(df['super_asset_nm'], inplace=True)

  # disp_rtm 문자열을 분 단위로 변경
  def convert_runtime(runtime_str):
    # 입력값이 NaN이면 0 반환
    if pd.isna(runtime_str):
        return 0

    hours = int(runtime_str.split(':')[0])
    minutes = int(runtime_str.split(':')[1])
    total_minutes = hours * 60 + minutes
    return total_minutes

  df['disp_rtm'] = df['disp_rtm'].apply(convert_runtime)

  # 셋탑번호가 66056000인 것 삭제 - content 에서 이상치 아이디로 판별
  df = df[df['subsr'] != 66056000]

  # index reset
  df = df.reset_index(drop=True)

  return df

# %%
df = preprocessing_con(con89)
df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['series_nm'] = df['series_nm'].str.replace(r'\([^()]*\)', '', regex=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['series_nm'] = df['series_nm'].str.replace(r'\[[^\[\]]*\]', '', regex=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['series_nm'] = df['series_nm'].str.replace(r'\.\.\.', '', regex=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['series_nm'] = df['series_nm'].str.replace(r'…', '', regex=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['series_nm'] = df['series_nm'].str.replace('-', ' ')
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['series_nm'] = df['series_nm'].str.rstrip('.')
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['super_asset_nm'] = df['super_asset_nm'].str.replace(r'\([^()]*\)', '', regex=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['super_asset_nm'] = df['super_asset_nm'].str.replace(r'\[[^\[\]]*\]', '', regex=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['super_asset_nm'] = df['super_asset_nm'].str.replace(r'\.\.\.', '', regex=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['super_asset_nm'] = df['super_asset_nm'].str.replace(r'…', '', regex=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['super_asset_nm'] = df['super_asset_nm'].str.replace('-', ' ')
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['super_asset_nm'] = df['super_asset_nm'].str.rstrip('.')
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['series_nm'] = df['series_nm'].str.replace(r'무삭제판|무삭제', '', regex = True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['series_nm'] = df['series_nm'].str.replace(r'실사판', '', regex = True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['series_nm'] = df['series_nm'].str.replace(r'\d+회$', '', regex=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['series_nm'] = df['series_nm'].str.replace(r'\d+회\.', '', regex=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['series_nm'] = df['series_nm'].str.replace(r'\d+화$', '', regex = True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['series_nm'] = df['series_nm'].str.strip()
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['series_nm'] = df['series_nm'].str.rstrip('.')
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['super_asset_nm'] = df['super_asset_nm'].str.replace(r'무삭제판|무삭제', '', regex = True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['super_asset_nm'] = df['super_asset_nm'].str.replace(r'실사판', '', regex = True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['super_asset_nm'] = df['super_asset_nm'].str.replace(r'\d+회$', '', regex=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['super_asset_nm'] = df['super_asset_nm'].str.replace(r'\d+회\.', '', regex=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['super_asset_nm'] = df['super_asset_nm'].str.replace(r'\d+화$', '', regex = True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['super_asset_nm'] = df['super_asset_nm'].str.strip()
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['super_asset_nm'] = df['super_asset_nm'].str.rstrip('.')
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['series_nm'].fillna(df['super_asset_nm'], inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19260\3741496128.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['disp_rtm'] = df['disp_rtm'].apply(convert_runtime)
#       subsr     series_nm super_asset_nm ct_cl genre_of_ct_cl  \
# 0  65968000     핑크퐁 동물 동요      핑크퐁 동물 동요    키즈             기타
# 1  65968000     핑크퐁 동물 동요      핑크퐁 동물 동요    키즈             기타
# 2  63086000  지니강이 플러스 시즌7   지니강이 플러스 시즌7    키즈             기타
# 3  63086000  지니강이 플러스 시즌9   지니강이 플러스 시즌9    키즈             기타
# 4  62733000    엘리가간다 시즌12     엘리가간다 시즌12    키즈             기타
#
#                                                 SMRY  ACTR_DISP  disp_rtm  \
# 0  겨울잠. 숲, 바다, 극지방 등 세계 여러 곳에 사는 동물 친구들을 만나러 가자! ...        핑크퐁         1
# 1  겨울잠. 숲, 바다, 극지방 등 세계 여러 곳에 사는 동물 친구들을 만나러 가자! ...        핑크퐁         1
# 2  로봇 세상에서 킥보드를 타요. 로보카 폴리 브룸스 타운에서 킥보드를 타요~ / 새로...  헤이지니,럭키강이        11
# 3      지니가 화장품으로 슬라임을 만들어요. / 슈퍼히어로 강이! 문을 열면 춤을 춰요.  헤이지니,럭키강이        11
# 4                                   미니 시리얼 팬케이크 만들기.          -        13
#
#            log_dt
# 0  20230813071155
# 1  20230813071215
# 2  20230827145542
# 3  20230827152417
# 4  20230816112816

# %%
# Category 구분
df['Category'] = np.where(df['ct_cl'] == '영화', '영화', np.where(df['ct_cl'] == '키즈', '키즈', 'TV프로그램'))
df
# Out:
#           subsr     series_nm super_asset_nm ct_cl genre_of_ct_cl  \
# 0      65968000     핑크퐁 동물 동요      핑크퐁 동물 동요    키즈             기타
# 1      65968000     핑크퐁 동물 동요      핑크퐁 동물 동요    키즈             기타
# 2      63086000  지니강이 플러스 시즌7   지니강이 플러스 시즌7    키즈             기타
# 3      63086000  지니강이 플러스 시즌9   지니강이 플러스 시즌9    키즈             기타
# 4      62733000    엘리가간다 시즌12     엘리가간다 시즌12    키즈             기타
# ...         ...           ...            ...   ...            ...
# 21124  64551000         슈퍼 토끼          슈퍼 토끼    키즈             학습
# 21125  64551000         슈퍼 토끼          슈퍼 토끼    키즈             학습
# 21126  64551000         슈퍼 토끼          슈퍼 토끼    키즈             학습
# 21127  64551000         슈퍼 토끼          슈퍼 토끼    키즈             학습
# 21128  64551000         슈퍼 토끼          슈퍼 토끼    키즈             학습
#
#                                                     SMRY  ACTR_DISP  disp_rtm  \
# 0      겨울잠. 숲, 바다, 극지방 등 세계 여러 곳에 사는 동물 친구들을 만나러 가자! ...        핑크퐁         1
# 1      겨울잠. 숲, 바다, 극지방 등 세계 여러 곳에 사는 동물 친구들을 만나러 가자! ...        핑크퐁         1
# 2      로봇 세상에서 킥보드를 타요. 로보카 폴리 브룸스 타운에서 킥보드를 타요~ / 새로...  헤이지니,럭키강이        11
# 3          지니가 화장품으로 슬라임을 만들어요. / 슈퍼히어로 강이! 문을 열면 춤을 춰요.  헤이지니,럭키강이        11
# 4                                       미니 시리얼 팬케이크 만들기.          -        13
# ...                                                  ...        ...       ...
# 21124  [교보문고,YES24,알라딘 베스트셀러] 경주에 진 그 토끼는 어떻게 되었을까? 내...          -        12
# 21125  [교보문고,YES24,알라딘 베스트셀러] 경주에 진 그 토끼는 어떻게 되었을까? 내...          -        12
# 21126  [교보문고,YES24,알라딘 베스트셀러] 경주에 진 그 토끼는 어떻게 되었을까? 내...          -        12
# 21127  [교보문고,YES24,알라딘 베스트셀러] 경주에 진 그 토끼는 어떻게 되었을까? 내...          -        12
# 21128  [교보문고,YES24,알라딘 베스트셀러] 경주에 진 그 토끼는 어떻게 되었을까? 내...          -        12
#
#                log_dt Category
# 0      20230813071155       키즈
# 1      20230813071215       키즈
# 2      20230827145542       키즈
# 3      20230827152417       키즈
# 4      20230816112816       키즈
# ...               ...      ...
# 21124  20230930121656       키즈
# 21125  20230930121646       키즈
# 21126  20230930121655       키즈
# 21127  20230930121655       키즈
# 21128  20230930121654       키즈
#
# [21129 rows x 10 columns]

# %%
# name에서 띄어쓰기 전부 제거한 열 생성
df['rename'] = df['series_nm'].apply(lambda x: x.replace(' ', '') if isinstance(x, str) else x)
df
# Out:
#           subsr     series_nm super_asset_nm ct_cl genre_of_ct_cl  \
# 0      65968000     핑크퐁 동물 동요      핑크퐁 동물 동요    키즈             기타
# 1      65968000     핑크퐁 동물 동요      핑크퐁 동물 동요    키즈             기타
# 2      63086000  지니강이 플러스 시즌7   지니강이 플러스 시즌7    키즈             기타
# 3      63086000  지니강이 플러스 시즌9   지니강이 플러스 시즌9    키즈             기타
# 4      62733000    엘리가간다 시즌12     엘리가간다 시즌12    키즈             기타
# ...         ...           ...            ...   ...            ...
# 21124  64551000         슈퍼 토끼          슈퍼 토끼    키즈             학습
# 21125  64551000         슈퍼 토끼          슈퍼 토끼    키즈             학습
# 21126  64551000         슈퍼 토끼          슈퍼 토끼    키즈             학습
# 21127  64551000         슈퍼 토끼          슈퍼 토끼    키즈             학습
# 21128  64551000         슈퍼 토끼          슈퍼 토끼    키즈             학습
#
#                                                     SMRY  ACTR_DISP  disp_rtm  \
# 0      겨울잠. 숲, 바다, 극지방 등 세계 여러 곳에 사는 동물 친구들을 만나러 가자! ...        핑크퐁         1
# 1      겨울잠. 숲, 바다, 극지방 등 세계 여러 곳에 사는 동물 친구들을 만나러 가자! ...        핑크퐁         1
# 2      로봇 세상에서 킥보드를 타요. 로보카 폴리 브룸스 타운에서 킥보드를 타요~ / 새로...  헤이지니,럭키강이        11
# 3          지니가 화장품으로 슬라임을 만들어요. / 슈퍼히어로 강이! 문을 열면 춤을 춰요.  헤이지니,럭키강이        11
# 4                                       미니 시리얼 팬케이크 만들기.          -        13
# ...                                                  ...        ...       ...
# 21124  [교보문고,YES24,알라딘 베스트셀러] 경주에 진 그 토끼는 어떻게 되었을까? 내...          -        12
# 21125  [교보문고,YES24,알라딘 베스트셀러] 경주에 진 그 토끼는 어떻게 되었을까? 내...          -        12
# 21126  [교보문고,YES24,알라딘 베스트셀러] 경주에 진 그 토끼는 어떻게 되었을까? 내...          -        12
# 21127  [교보문고,YES24,알라딘 베스트셀러] 경주에 진 그 토끼는 어떻게 되었을까? 내...          -        12
# 21128  [교보문고,YES24,알라딘 베스트셀러] 경주에 진 그 토끼는 어떻게 되었을까? 내...          -        12
#
#                log_dt Category      rename
# 0      20230813071155       키즈     핑크퐁동물동요
# 1      20230813071215       키즈     핑크퐁동물동요
# 2      20230827145542       키즈  지니강이플러스시즌7
# 3      20230827152417       키즈  지니강이플러스시즌9
# 4      20230816112816       키즈   엘리가간다시즌12
# ...               ...      ...         ...
# 21124  20230930121656       키즈        슈퍼토끼
# 21125  20230930121646       키즈        슈퍼토끼
# 21126  20230930121655       키즈        슈퍼토끼
# 21127  20230930121655       키즈        슈퍼토끼
# 21128  20230930121654       키즈        슈퍼토끼
#
# [21129 rows x 11 columns]

# %%
# vod_list에서 vod_id 가져오기
vod_list = pd.read_csv('../data/전처리data/vod_id_origin.csv', encoding='cp949')
vod_list.columns = ['series_nm', 'summary', 'actors', 'director', 'ct_cl', 'genre_of_ct_cl', 
                    'Category', 'runningtime', 'SMRY', 'rename', 'counts', 'vod_id']
vod_list = vod_list[['series_nm', 'vod_id', 'ct_cl', 'genre_of_ct_cl', 'Category', 'rename']]
vod_list
# Out:
#              series_nm  vod_id     ct_cl genre_of_ct_cl Category       rename
# 0       와이낫크루   뜻밖의 여행       0  TV 연예/오락             기타   TV프로그램   와이낫크루뜻밖의여행
# 1              그레이트 뷰티       1        영화             기타       영화       그레이트뷰티
# 2                  해안선       2        영화        액션/어드벤쳐       영화          해안선
# 3                아는 형님       3  TV 연예/오락             기타   TV프로그램         아는형님
# 4                   베놈       4        영화        액션/어드벤쳐       영화           베놈
# ...                ...     ...       ...            ...      ...          ...
# 4710  베놈 2: 렛 데어 비 카니지    4710        영화        액션/어드벤쳐       영화  베놈2:렛데어비카니지
# 4711              성월동화    4711        영화             멜로       영화         성월동화
# 4712       다큐인사이트 코드블루    4712  TV 시사/교양             기타   TV프로그램   다큐인사이트코드블루
# 4713         캠프 제로베이스원    4713  TV 연예/오락             기타   TV프로그램     캠프제로베이스원
# 4714          연애 말고 결혼    4714     TV드라마         외화 시리즈   TV프로그램       연애말고결혼
#
# [4715 rows x 6 columns]

# %%
vod_list.to_csv('../data/전처리data/vod_list_origin.csv', index=False, encoding="cp949")

# %%
vod_id = pd.read_csv('../data/전처리data/vod_id_cut_columns.csv', encoding="cp949")
vod_id.head(2)
# Out:
#         series_nm  vod_id     ct_cl genre_of_ct_cl Category      rename
# 0  와이낫크루   뜻밖의 여행       0  TV 연예/오락             기타   TV프로그램  와이낫크루뜻밖의여행
# 1         그레이트 뷰티       1        영화             기타       영화      그레이트뷰티

# %%
# rename, Category 기준으로 vod_id 붙임
df_add_id = pd.merge(df, vod_id[['ct_cl', 'genre_of_ct_cl', 'rename']], on=['rename', 'genre_of_ct_cl', 'Category'], how='left')
df_add_id
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\user\Documents\LG_DX_Project\LGHV-final-project\전처리\content_series_nm전처리_origin.ipynb Cell 15 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/LG_DX_Project/LGHV-final-project/%EC%A0%84%EC%B2%98%EB%A6%AC/content_series_nm%EC%A0%84%EC%B2%98%EB%A6%AC_origin.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> # rename, Category 기준으로 vod_id 붙임
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/LG_DX_Project/LGHV-final-project/%EC%A0%84%EC%B2%98%EB%A6%AC/content_series_nm%EC%A0%84%EC%B2%98%EB%A6%AC_origin.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> df_add_id = pd.merge(df, vod_id[['rename', 'ct_cl', 'genre_of_ct_cl']], on=['rename', 'genre_of_ct_cl', 'Category'], how='left')
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/LG_DX_Project/LGHV-final-project/%EC%A0%84%EC%B2%98%EB%A6%AC/content_series_nm%EC%A0%84%EC%B2%98%EB%A6%AC_origin.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> df_add_id
#
# File c:\Users\user\AppData\Local\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File c:\Users\user\AppData\Local\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:703, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     696 self._cross = cross_col
#     698 # note this function has side effects
#     699 (
#     700     self.left_join_keys,
#     701     self.right_join_keys,
#     702     self.join_names,
# --> 703 ) = self._get_merge_keys()
#     705 # validate the merge keys dtypes. We may need to coerce
#     706 # to avoid incompatible dtypes
#     707 self._maybe_coerce_merge_keys()
#
# File c:\Users\user\AppData\Local\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:1162, in _MergeOperation._get_merge_keys(self)
#    1160 rk = cast(Hashable, rk)
#    1161 if rk is not None:
# -> 1162     right_keys.append(right._get_label_or_level_values(rk))
#    1163 else:
#    1164     # work-around for merge_asof(right_index=True)
#    1165     right_keys.append(right.index)
#
# File c:\Users\user\AppData\Local\anaconda3\lib\site-packages\pandas\core\generic.py:1850, in NDFrame._get_label_or_level_values(self, key, axis)
#    1844     values = (
#    1845         self.axes[axis]
#    1846         .get_level_values(key)  # type: ignore[assignment]
#    1847         ._values
#    1848     )
#    1849 else:
# -> 1850     raise KeyError(key)
#    1852 # Check for duplicates
#    1853 if values.ndim > 1:
#
# KeyError: 'Category'

# %%
df_add_id[df_add_id['vod_id'].isna()]
# Out:
# Empty DataFrame
# Columns: [subsr, series_nm, super_asset_nm, ct_cl, genre_of_ct_cl, SMRY, ACTR_DISP, disp_rtm, log_dt, Category, rename, vod_id]
# Index: []

# %%
# 제목만 전처리
df_add_id.to_csv('../data/전처리data/con_prepro_series_nm.csv', index=False, encoding="cp949")
