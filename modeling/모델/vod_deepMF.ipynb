# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings(action='ignore')

# %%
vod = pd.read_csv('../data/vod89.csv')
vod
# Out:
#         userid       program  main_cat  sub_cat     score category      rename
# 0     59879000     소방서 옆 경찰서     TV드라마       기타  0.244476   TV프로그램     소방서옆경찰서
# 1     59879000        신성한 이혼     TV드라마       기타  0.738281   TV프로그램       신성한이혼
# 2     59895000       금이야 옥이야     TV드라마       기타  1.000000   TV프로그램      금이야옥이야
# 3     59900000  2022 역사저널 그날  TV 시사/교양       기타  0.215482   TV프로그램  2022역사저널그날
# 4     59900000       그것이알고싶다  TV 시사/교양       기타  0.374741   TV프로그램     그것이알고싶다
# ...        ...           ...       ...      ...       ...      ...         ...
# 1494  67140000      경남 통영 2부      우리동네    연예/오락  0.292893   TV프로그램      경남통영2부
# 1495  67140000            밀수        영화  액션/어드벤쳐  0.250000       영화          밀수
# 1496  67140000    잠자는 숲속의 공주        키즈       기타  0.292893       키즈    잠자는숲속의공주
# 1497  67148000  타요의 씽씽극장 동요2        키즈       기타  0.988951       키즈  타요의씽씽극장동요2
# 1498  67164000            밀수        영화  액션/어드벤쳐  0.500000       영화          밀수
#
# [1499 rows x 7 columns]

# %%
vod_id = pd.read_csv('../data/vod_add_id.csv', index_col=0)
vod_id = vod_id[['rename', 'Category', 'vod_id']]
vod_id.columns = ['rename', 'category', 'vod_id']
vod_id
# Out:
#            rename category  vod_id
# 0      와이낫크루뜻밖의여행   TV프로그램       0
# 1          그레이트뷰티       영화       1
# 2             해안선       영화       2
# 3            아는형님   TV프로그램       3
# 4              베놈       영화       4
# ...           ...      ...     ...
# 4710  베놈2:렛데어비카니지       영화    4710
# 4711         성월동화       영화    4711
# 4712   다큐인사이트코드블루   TV프로그램    4712
# 4713     캠프제로베이스원   TV프로그램    4713
# 4714       연애말고결혼   TV프로그램    4714
#
# [4715 rows x 3 columns]

# %%
vod1 = vod.merge(vod_id, on = ['rename', 'category'], how = 'left')
userid = pd.DataFrame(vod1['userid'].unique())
userid.columns = ['userid']
userid['user_id'] = userid.index

vod1 = vod1.merge(userid, on = ['userid'], how = 'left')
vod1
# Out:
#         userid       program  main_cat  sub_cat     score category  \
# 0     59879000     소방서 옆 경찰서     TV드라마       기타  0.244476   TV프로그램
# 1     59879000        신성한 이혼     TV드라마       기타  0.738281   TV프로그램
# 2     59895000       금이야 옥이야     TV드라마       기타  1.000000   TV프로그램
# 3     59900000  2022 역사저널 그날  TV 시사/교양       기타  0.215482   TV프로그램
# 4     59900000       그것이알고싶다  TV 시사/교양       기타  0.374741   TV프로그램
# ...        ...           ...       ...      ...       ...      ...
# 1494  67140000      경남 통영 2부      우리동네    연예/오락  0.292893   TV프로그램
# 1495  67140000            밀수        영화  액션/어드벤쳐  0.250000       영화
# 1496  67140000    잠자는 숲속의 공주        키즈       기타  0.292893       키즈
# 1497  67148000  타요의 씽씽극장 동요2        키즈       기타  0.988951       키즈
# 1498  67164000            밀수        영화  액션/어드벤쳐  0.500000       영화
#
#           rename  vod_id  user_id
# 0        소방서옆경찰서    2092        0
# 1          신성한이혼    1190        0
# 2         금이야옥이야     784        1
# 3     2022역사저널그날     572        2
# 4        그것이알고싶다     297        2
# ...          ...     ...      ...
# 1494      경남통영2부    4396      329
# 1495          밀수    2865      329
# 1496    잠자는숲속의공주     689      329
# 1497  타요의씽씽극장동요2     880      330
# 1498          밀수    2865      331
#
# [1499 rows x 9 columns]

# %%
vod1.to_csv('../data/vod_score.csv', index = 0)

# %%
vod_score = pd.read_csv('../data/vod_score.csv')
vod_score = vod_score[['user_id', 'vod_id', 'score']]
vod_score
# Out:
#       user_id  vod_id     score
# 0           0     572  0.215482
# 1           0     297  0.374741
# 2           0     149  0.292893
# 3           0    2537  0.292893
# 4           0    3314  0.292893
# ...       ...     ...       ...
# 1040       74      13  0.132597
# 1041       74     315  0.952381
# 1042       74      16  0.100000
# 1043       74     341  0.292893
# 1044       74     289  0.086926
#
# [1045 rows x 3 columns]

# %%
# vod_score['score'] = pd.cut(vod_score['score'], bins = [0,0.2,0.4,0.6,0.8, 1], labels = [1,2,3,4,5])
# vod_score
# Out:
#       user_id  vod_id score
# 0           0     572     2
# 1           0     297     2
# 2           0     149     2
# 3           0    2537     2
# 4           0    3314     2
# ...       ...     ...   ...
# 1040       74      13     1
# 1041       74     315     5
# 1042       74      16     1
# 1043       74     341     2
# 1044       74     289     1
#
# [1045 rows x 3 columns]

# %%
# import matplotlib.pyplot as plt
# vod_score.score.hist(bins = 5)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

vod_train, vod_test = train_test_split(vod_score, test_size = 0.2, stratify=vod_score['user_id'], random_state = 42)
vod_train
# Out:
#       user_id  vod_id     score
# 1041       74     315  0.952381
# 760        63    1624  0.292893
# 610        45     796  0.949072
# 204        13    2058  0.292893
# 745        62      23  0.292893
# ...       ...     ...       ...
# 922        69     686  0.292893
# 592        43      16  0.025641
# 404        29    4103  0.646447
# 8           1    1190  0.082031
# 254        18     177  0.292893
#
# [836 rows x 3 columns]

# %%
from sklearn.utils import shuffle
TRAIN_SIZE = 0.75
vod_score = shuffle(vod_score)
cutoff = int(TRAIN_SIZE * len(vod_score))

vod_train = vod_score.iloc[:cutoff]
vod_test = vod_score.iloc[cutoff:]

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Dot, Add, Flatten
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import SGD, Adamax

# variable 초기화
K = 100
mu = vod_train.score.mean()
M = vod_score.user_id.max() + 1
N = vod_score.vod_id.max() + 1

# Defining RMSE measure
def RMSE(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true - y_pred)))

# Keras model
user = Input(shape = (1,))  # User input
item = Input(shape = (1,))  # Item input
P_embedding = Embedding(M, K, embeddings_regularizer = l2())(user)  # (M, 1, K)
Q_embedding = Embedding(N, K, embeddings_regularizer = l2())(item)  # (N, 1, K)
user_bias = Embedding(M, 1, embeddings_regularizer=l2())(user) # User bias term (M, 1, )
item_bias = Embedding(N, 1, embeddings_regularizer=l2())(item) # Item bias term (N, 1, )

# Concatenate layers
from tensorflow.keras.layers import Dense, Concatenate, Activation
P_embedding = Flatten()(P_embedding)    # (K, )
Q_embedding = Flatten()(Q_embedding)    # (K, )
user_bias = Flatten()(user_bias)    # (1, )
item_bias = Flatten()(item_bias)    # (1, )
R = Concatenate()([P_embedding, Q_embedding, user_bias, item_bias]) # (2K + 2, )

# Neural network
R = Dense(1024)(R)
R = Activation('relu')(R)
R = Dense(256)(R)
R = Activation('linear')(R)
R = Dense(1)(R)

# # R = Dot(axes = 2)([P_embedding, Q_embedding])
# R = layers.dot([P_embedding, Q_embedding], axes = 2)    # (1, 1, 1)
# # R = Add()([R, user_bias, item_bias])
# R = layers.add([R, user_bias, item_bias])
# R = Flatten()(R)    # (1, 1)

# Model setting
model = Model(inputs = [user, item], outputs = R)
model.compile(
    loss = RMSE,
    optimizer = SGD(),
    metrics = [RMSE]
)
model.summary()

# Model fitting
result = model.fit(
    x = [vod_train.user_id.values, vod_train.vod_id.values],
    y = vod_train.score.values - mu,
    epochs = 200,
    batch_size = 256,
    validation_data = (
        [vod_test.user_id.values, vod_test.vod_id.values],
        vod_test.score.values - mu
    )
)
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_17 (InputLayer)       [(None, 1)]                  0         []
#
#  input_18 (InputLayer)       [(None, 1)]                  0         []
#
#  embedding_32 (Embedding)    (None, 1, 100)               7500      ['input_17[0][0]']
#
#  embedding_33 (Embedding)    (None, 1, 100)               470100    ['input_18[0][0]']
#
#  embedding_34 (Embedding)    (None, 1, 1)                 75        ['input_17[0][0]']
#
#  embedding_35 (Embedding)    (None, 1, 1)                 4701      ['input_18[0][0]']
#
#  flatten_29 (Flatten)        (None, 100)                  0         ['embedding_32[0][0]']
#
#  flatten_30 (Flatten)        (None, 100)                  0         ['embedding_33[0][0]']
#
#  flatten_31 (Flatten)        (None, 1)                    0         ['embedding_34[0][0]']
#
#  flatten_32 (Flatten)        (None, 1)                    0         ['embedding_35[0][0]']
#
#  concatenate_7 (Concatenate  (None, 202)                  0         ['flatten_29[0][0]',
#  )                                                                   'flatten_30[0][0]',
#                                                                      'flatten_31[0][0]',
#                                                                      'flatten_32[0][0]']
#
#  dense_21 (Dense)            (None, 1024)                 207872    ['concatenate_7[0][0]']
#
#  activation_14 (Activation)  (None, 1024)                 0         ['dense_21[0][0]']
#
#  dense_22 (Dense)            (None, 256)                  262400    ['activation_14[0][0]']
#
#  activation_15 (Activation)  (None, 256)                  0         ['dense_22[0][0]']
#
#  dense_23 (Dense)            (None, 1)                    257       ['activation_15[0][0]']
#
# ==================================================================================================
# Total params: 952905 (3.64 MB)
# Trainable params: 952905 (3.64 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/200
# 4/4 [==============================] - 1s 63ms/step - loss: 4.2297 - RMSE: 0.2087 - val_loss: 4.2381 - val_RMSE: 0.2208
# Epoch 2/200
# 4/4 [==============================] - 0s 24ms/step - loss: 4.2229 - RMSE: 0.2122 - val_loss: 4.2315 - val_RMSE: 0.2207
# Epoch 3/200
# 4/4 [==============================] - 0s 22ms/step - loss: 4.2164 - RMSE: 0.2057 - val_loss: 4.2250 - val_RMSE: 0.2206
# Epoch 4/200
# 4/4 [==============================] - 0s 21ms/step - loss: 4.2096 - RMSE: 0.2072 - val_loss: 4.2185 - val_RMSE: 0.2205
# Epoch 5/200
# 4/4 [==============================] - 0s 21ms/step - loss: 4.2033 - RMSE: 0.2057 - val_loss: 4.2119 - val_RMSE: 0.2203
# Epoch 6/200
# 4/4 [==============================] - 0s 23ms/step - loss: 4.1966 - RMSE: 0.2038 - val_loss: 4.2054 - val_RMSE: 0.2202
# Epoch 7/200
# 4/4 [==============================] - 0s 25ms/step - loss: 4.1901 - RMSE: 0.2052 - val_loss: 4.1989 - val_RMSE: 0.2201
# Epoch 8/200
# 4/4 [==============================] - 0s 20ms/step - loss: 4.1835 - RMSE: 0.2042 - val_loss: 4.1924 - val_RMSE: 0.2199
# Epoch 9/200
# 4/4 [==============================] - 0s 16ms/step - loss: 4.1766 - RMSE: 0.2075 - val_loss: 4.1860 - val_RMSE: 0.2198
# Epoch 10/200
# 4/4 [==============================] - 0s 21ms/step - loss: 4.1703 - RMSE: 0.2081 - val_loss: 4.1796 - val_RMSE: 0.2198
# Epoch 11/200
# 4/4 [==============================] - 0s 21ms/step - loss: 4.1638 - RMSE: 0.2011 - val_loss: 4.1730 - val_RMSE: 0.2196
# Epoch 12/200
# 4/4 [==============================] - 0s 22ms/step - loss: 4.1571 - RMSE: 0.2059 - val_loss: 4.1666 - val_RMSE: 0.2194
# Epoch 13/200
# 4/4 [==============================] - 0s 19ms/step - loss: 4.1505 - RMSE: 0.2000 - val_loss: 4.1602 - val_RMSE: 0.2194
# Epoch 14/200
# 4/4 [==============================] - 0s 21ms/step - loss: 4.1444 - RMSE: 0.2014 - val_loss: 4.1538 - val_RMSE: 0.2193
# Epoch 15/200
# 4/4 [==============================] - 0s 21ms/step - loss: 4.1378 - RMSE: 0.2040 - val_loss: 4.1473 - val_RMSE: 0.2191
# Epoch 16/200
# 4/4 [==============================] - 0s 21ms/step - loss: 4.1313 - RMSE: 0.2104 - val_loss: 4.1409 - val_RMSE: 0.2190
# Epoch 17/200
# 4/4 [==============================] - 0s 21ms/step - loss: 4.1246 - RMSE: 0.2054 - val_loss: 4.1345 - val_RMSE: 0.2188
# Epoch 18/200
# 4/4 [==============================] - 0s 21ms/step - loss: 4.1181 - RMSE: 0.2035 - val_loss: 4.1281 - val_RMSE: 0.2187
# Epoch 19/200
# 4/4 [==============================] - 0s 22ms/step - loss: 4.1120 - RMSE: 0.2003 - val_loss: 4.1218 - val_RMSE: 0.2186
# Epoch 20/200
# 4/4 [==============================] - 0s 20ms/step - loss: 4.1055 - RMSE: 0.2013 - val_loss: 4.1154 - val_RMSE: 0.2185
# Epoch 21/200
# 4/4 [==============================] - 0s 21ms/step - loss: 4.0991 - RMSE: 0.2020 - val_loss: 4.1091 - val_RMSE: 0.2183
# Epoch 22/200
# 4/4 [==============================] - 0s 20ms/step - loss: 4.0921 - RMSE: 0.1990 - val_loss: 4.1028 - val_RMSE: 0.2183
# Epoch 23/200
# 4/4 [==============================] - 0s 19ms/step - loss: 4.0867 - RMSE: 0.2048 - val_loss: 4.0964 - val_RMSE: 0.2181
# Epoch 24/200
# 4/4 [==============================] - 0s 21ms/step - loss: 4.0798 - RMSE: 0.2084 - val_loss: 4.0901 - val_RMSE: 0.2181
# Epoch 25/200
# 4/4 [==============================] - 0s 19ms/step - loss: 4.0738 - RMSE: 0.2045 - val_loss: 4.0838 - val_RMSE: 0.2179
# Epoch 26/200
# 4/4 [==============================] - 0s 19ms/step - loss: 4.0674 - RMSE: 0.2049 - val_loss: 4.0775 - val_RMSE: 0.2177
# Epoch 27/200
# 4/4 [==============================] - 0s 19ms/step - loss: 4.0610 - RMSE: 0.2001 - val_loss: 4.0711 - val_RMSE: 0.2176
# Epoch 28/200
# 4/4 [==============================] - 0s 29ms/step - loss: 4.0540 - RMSE: 0.2006 - val_loss: 4.0649 - val_RMSE: 0.2175
# Epoch 29/200
# 4/4 [==============================] - 0s 20ms/step - loss: 4.0482 - RMSE: 0.2084 - val_loss: 4.0586 - val_RMSE: 0.2174
# Epoch 30/200
# 4/4 [==============================] - 0s 19ms/step - loss: 4.0419 - RMSE: 0.1999 - val_loss: 4.0523 - val_RMSE: 0.2172
# Epoch 31/200
# 4/4 [==============================] - 0s 18ms/step - loss: 4.0359 - RMSE: 0.2047 - val_loss: 4.0461 - val_RMSE: 0.2171
# Epoch 32/200
# 4/4 [==============================] - 0s 19ms/step - loss: 4.0291 - RMSE: 0.1989 - val_loss: 4.0398 - val_RMSE: 0.2170
# Epoch 33/200
# 4/4 [==============================] - 0s 22ms/step - loss: 4.0232 - RMSE: 0.2044 - val_loss: 4.0336 - val_RMSE: 0.2169
# Epoch 34/200
# 4/4 [==============================] - 0s 20ms/step - loss: 4.0167 - RMSE: 0.2001 - val_loss: 4.0274 - val_RMSE: 0.2167
# Epoch 35/200
# 4/4 [==============================] - 0s 20ms/step - loss: 4.0106 - RMSE: 0.1994 - val_loss: 4.0212 - val_RMSE: 0.2166
# Epoch 36/200
# 4/4 [==============================] - 0s 19ms/step - loss: 4.0044 - RMSE: 0.2036 - val_loss: 4.0150 - val_RMSE: 0.2165
# Epoch 37/200
# 4/4 [==============================] - 0s 22ms/step - loss: 3.9979 - RMSE: 0.1939 - val_loss: 4.0088 - val_RMSE: 0.2164
# Epoch 38/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.9920 - RMSE: 0.1990 - val_loss: 4.0027 - val_RMSE: 0.2164
# Epoch 39/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.9857 - RMSE: 0.1967 - val_loss: 3.9965 - val_RMSE: 0.2163
# Epoch 40/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.9792 - RMSE: 0.2045 - val_loss: 3.9903 - val_RMSE: 0.2160
# Epoch 41/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.9732 - RMSE: 0.2009 - val_loss: 3.9841 - val_RMSE: 0.2159
# Epoch 42/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.9670 - RMSE: 0.2030 - val_loss: 3.9780 - val_RMSE: 0.2158
# Epoch 43/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.9600 - RMSE: 0.2091 - val_loss: 3.9719 - val_RMSE: 0.2157
# Epoch 44/200
# 4/4 [==============================] - 0s 20ms/step - loss: 3.9548 - RMSE: 0.2041 - val_loss: 3.9658 - val_RMSE: 0.2157
# Epoch 45/200
# 4/4 [==============================] - 0s 17ms/step - loss: 3.9475 - RMSE: 0.2116 - val_loss: 3.9598 - val_RMSE: 0.2156
# Epoch 46/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.9425 - RMSE: 0.1989 - val_loss: 3.9535 - val_RMSE: 0.2153
# Epoch 47/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.9359 - RMSE: 0.1939 - val_loss: 3.9475 - val_RMSE: 0.2152
# Epoch 48/200
# 4/4 [==============================] - 0s 22ms/step - loss: 3.9299 - RMSE: 0.1934 - val_loss: 3.9415 - val_RMSE: 0.2153
# Epoch 49/200
# 4/4 [==============================] - 0s 22ms/step - loss: 3.9243 - RMSE: 0.1981 - val_loss: 3.9354 - val_RMSE: 0.2151
# Epoch 50/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.9180 - RMSE: 0.1965 - val_loss: 3.9292 - val_RMSE: 0.2149
# Epoch 51/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.9117 - RMSE: 0.2046 - val_loss: 3.9232 - val_RMSE: 0.2148
# Epoch 52/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.9056 - RMSE: 0.2035 - val_loss: 3.9172 - val_RMSE: 0.2147
# Epoch 53/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.8996 - RMSE: 0.2021 - val_loss: 3.9111 - val_RMSE: 0.2145
# Epoch 54/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.8936 - RMSE: 0.1945 - val_loss: 3.9052 - val_RMSE: 0.2145
# Epoch 55/200
# 4/4 [==============================] - 0s 24ms/step - loss: 3.8869 - RMSE: 0.2072 - val_loss: 3.8991 - val_RMSE: 0.2143
# Epoch 56/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.8802 - RMSE: 0.2049 - val_loss: 3.8931 - val_RMSE: 0.2142
# Epoch 57/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.8752 - RMSE: 0.1994 - val_loss: 3.8871 - val_RMSE: 0.2141
# Epoch 58/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.8695 - RMSE: 0.1988 - val_loss: 3.8812 - val_RMSE: 0.2140
# Epoch 59/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.8631 - RMSE: 0.2010 - val_loss: 3.8752 - val_RMSE: 0.2139
# Epoch 60/200
# 4/4 [==============================] - 0s 20ms/step - loss: 3.8572 - RMSE: 0.1945 - val_loss: 3.8692 - val_RMSE: 0.2138
# Epoch 61/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.8508 - RMSE: 0.1988 - val_loss: 3.8633 - val_RMSE: 0.2137
# Epoch 62/200
# 4/4 [==============================] - 0s 15ms/step - loss: 3.8452 - RMSE: 0.1959 - val_loss: 3.8574 - val_RMSE: 0.2136
# Epoch 63/200
# 4/4 [==============================] - 0s 18ms/step - loss: 3.8389 - RMSE: 0.2006 - val_loss: 3.8514 - val_RMSE: 0.2135
# Epoch 64/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.8329 - RMSE: 0.2026 - val_loss: 3.8455 - val_RMSE: 0.2133
# Epoch 65/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.8275 - RMSE: 0.1950 - val_loss: 3.8396 - val_RMSE: 0.2132
# Epoch 66/200
# 4/4 [==============================] - 0s 30ms/step - loss: 3.8212 - RMSE: 0.1964 - val_loss: 3.8336 - val_RMSE: 0.2131
# Epoch 67/200
# 4/4 [==============================] - 0s 20ms/step - loss: 3.8153 - RMSE: 0.1959 - val_loss: 3.8277 - val_RMSE: 0.2130
# Epoch 68/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.8092 - RMSE: 0.1988 - val_loss: 3.8219 - val_RMSE: 0.2129
# Epoch 69/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.8036 - RMSE: 0.1998 - val_loss: 3.8160 - val_RMSE: 0.2128
# Epoch 70/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.7978 - RMSE: 0.1969 - val_loss: 3.8101 - val_RMSE: 0.2126
# Epoch 71/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.7916 - RMSE: 0.2030 - val_loss: 3.8043 - val_RMSE: 0.2126
# Epoch 72/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.7859 - RMSE: 0.1954 - val_loss: 3.7984 - val_RMSE: 0.2124
# Epoch 73/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.7799 - RMSE: 0.1961 - val_loss: 3.7926 - val_RMSE: 0.2123
# Epoch 74/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.7735 - RMSE: 0.1862 - val_loss: 3.7867 - val_RMSE: 0.2122
# Epoch 75/200
# 4/4 [==============================] - 0s 20ms/step - loss: 3.7683 - RMSE: 0.1979 - val_loss: 3.7809 - val_RMSE: 0.2121
# Epoch 76/200
# 4/4 [==============================] - 0s 22ms/step - loss: 3.7626 - RMSE: 0.1939 - val_loss: 3.7751 - val_RMSE: 0.2120
# Epoch 77/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.7565 - RMSE: 0.1918 - val_loss: 3.7694 - val_RMSE: 0.2120
# Epoch 78/200
# 4/4 [==============================] - 0s 20ms/step - loss: 3.7502 - RMSE: 0.2025 - val_loss: 3.7635 - val_RMSE: 0.2117
# Epoch 79/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.7447 - RMSE: 0.1954 - val_loss: 3.7577 - val_RMSE: 0.2116
# Epoch 80/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.7385 - RMSE: 0.1891 - val_loss: 3.7520 - val_RMSE: 0.2116
# Epoch 81/200
# 4/4 [==============================] - 0s 26ms/step - loss: 3.7334 - RMSE: 0.1965 - val_loss: 3.7462 - val_RMSE: 0.2114
# Epoch 82/200
# 4/4 [==============================] - 0s 27ms/step - loss: 3.7274 - RMSE: 0.1906 - val_loss: 3.7405 - val_RMSE: 0.2114
# Epoch 83/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.7218 - RMSE: 0.1929 - val_loss: 3.7347 - val_RMSE: 0.2112
# Epoch 84/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.7158 - RMSE: 0.2001 - val_loss: 3.7290 - val_RMSE: 0.2111
# Epoch 85/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.7101 - RMSE: 0.1971 - val_loss: 3.7232 - val_RMSE: 0.2110
# Epoch 86/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.7038 - RMSE: 0.1942 - val_loss: 3.7175 - val_RMSE: 0.2109
# Epoch 87/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.6986 - RMSE: 0.1903 - val_loss: 3.7118 - val_RMSE: 0.2107
# Epoch 88/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.6925 - RMSE: 0.1856 - val_loss: 3.7064 - val_RMSE: 0.2109
# Epoch 89/200
# 4/4 [==============================] - 0s 17ms/step - loss: 3.6871 - RMSE: 0.1981 - val_loss: 3.7004 - val_RMSE: 0.2106
# Epoch 90/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.6814 - RMSE: 0.1972 - val_loss: 3.6947 - val_RMSE: 0.2104
# Epoch 91/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.6757 - RMSE: 0.1898 - val_loss: 3.6890 - val_RMSE: 0.2103
# Epoch 92/200
# 4/4 [==============================] - 0s 24ms/step - loss: 3.6701 - RMSE: 0.1935 - val_loss: 3.6833 - val_RMSE: 0.2102
# Epoch 93/200
# 4/4 [==============================] - 0s 22ms/step - loss: 3.6640 - RMSE: 0.1846 - val_loss: 3.6779 - val_RMSE: 0.2103
# Epoch 94/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.6586 - RMSE: 0.1906 - val_loss: 3.6721 - val_RMSE: 0.2100
# Epoch 95/200
# 4/4 [==============================] - 0s 22ms/step - loss: 3.6530 - RMSE: 0.1902 - val_loss: 3.6664 - val_RMSE: 0.2098
# Epoch 96/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.6472 - RMSE: 0.1949 - val_loss: 3.6608 - val_RMSE: 0.2097
# Epoch 97/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.6416 - RMSE: 0.1919 - val_loss: 3.6551 - val_RMSE: 0.2096
# Epoch 98/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.6348 - RMSE: 0.1818 - val_loss: 3.6496 - val_RMSE: 0.2096
# Epoch 99/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.6304 - RMSE: 0.1903 - val_loss: 3.6439 - val_RMSE: 0.2094
# Epoch 100/200
# 4/4 [==============================] - 0s 17ms/step - loss: 3.6247 - RMSE: 0.1941 - val_loss: 3.6383 - val_RMSE: 0.2093
# Epoch 101/200
# 4/4 [==============================] - 0s 17ms/step - loss: 3.6185 - RMSE: 0.1981 - val_loss: 3.6327 - val_RMSE: 0.2092
# Epoch 102/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.6134 - RMSE: 0.1901 - val_loss: 3.6271 - val_RMSE: 0.2090
# Epoch 103/200
# 4/4 [==============================] - 0s 23ms/step - loss: 3.6078 - RMSE: 0.1892 - val_loss: 3.6216 - val_RMSE: 0.2089
# Epoch 104/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.6020 - RMSE: 0.1850 - val_loss: 3.6161 - val_RMSE: 0.2089
# Epoch 105/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.5966 - RMSE: 0.1898 - val_loss: 3.6105 - val_RMSE: 0.2088
# Epoch 106/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.5910 - RMSE: 0.1956 - val_loss: 3.6050 - val_RMSE: 0.2087
# Epoch 107/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.5855 - RMSE: 0.1921 - val_loss: 3.5995 - val_RMSE: 0.2085
# Epoch 108/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.5798 - RMSE: 0.1946 - val_loss: 3.5940 - val_RMSE: 0.2085
# Epoch 109/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.5743 - RMSE: 0.1933 - val_loss: 3.5884 - val_RMSE: 0.2083
# Epoch 110/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.5684 - RMSE: 0.1838 - val_loss: 3.5829 - val_RMSE: 0.2082
# Epoch 111/200
# 4/4 [==============================] - 0s 23ms/step - loss: 3.5631 - RMSE: 0.1901 - val_loss: 3.5774 - val_RMSE: 0.2081
# Epoch 112/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.5572 - RMSE: 0.1806 - val_loss: 3.5723 - val_RMSE: 0.2083
# Epoch 113/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.5520 - RMSE: 0.1842 - val_loss: 3.5665 - val_RMSE: 0.2079
# Epoch 114/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.5464 - RMSE: 0.1954 - val_loss: 3.5611 - val_RMSE: 0.2079
# Epoch 115/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.5406 - RMSE: 0.1978 - val_loss: 3.5556 - val_RMSE: 0.2078
# Epoch 116/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.5355 - RMSE: 0.1870 - val_loss: 3.5501 - val_RMSE: 0.2076
# Epoch 117/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.5300 - RMSE: 0.1920 - val_loss: 3.5446 - val_RMSE: 0.2075
# Epoch 118/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.5244 - RMSE: 0.1871 - val_loss: 3.5392 - val_RMSE: 0.2074
# Epoch 119/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.5190 - RMSE: 0.1849 - val_loss: 3.5340 - val_RMSE: 0.2075
# Epoch 120/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.5133 - RMSE: 0.1913 - val_loss: 3.5284 - val_RMSE: 0.2072
# Epoch 121/200
# 4/4 [==============================] - 0s 18ms/step - loss: 3.5079 - RMSE: 0.1903 - val_loss: 3.5230 - val_RMSE: 0.2071
# Epoch 122/200
# 4/4 [==============================] - 0s 15ms/step - loss: 3.5026 - RMSE: 0.1872 - val_loss: 3.5176 - val_RMSE: 0.2070
# Epoch 123/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.4962 - RMSE: 0.1887 - val_loss: 3.5122 - val_RMSE: 0.2069
# Epoch 124/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.4919 - RMSE: 0.1904 - val_loss: 3.5068 - val_RMSE: 0.2068
# Epoch 125/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.4864 - RMSE: 0.1835 - val_loss: 3.5015 - val_RMSE: 0.2067
# Epoch 126/200
# 4/4 [==============================] - 0s 18ms/step - loss: 3.4811 - RMSE: 0.1879 - val_loss: 3.4961 - val_RMSE: 0.2066
# Epoch 127/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.4756 - RMSE: 0.1888 - val_loss: 3.4909 - val_RMSE: 0.2066
# Epoch 128/200
# 4/4 [==============================] - 0s 18ms/step - loss: 3.4704 - RMSE: 0.1863 - val_loss: 3.4854 - val_RMSE: 0.2063
# Epoch 129/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.4650 - RMSE: 0.1868 - val_loss: 3.4800 - val_RMSE: 0.2062
# Epoch 130/200
# 4/4 [==============================] - 0s 15ms/step - loss: 3.4595 - RMSE: 0.1900 - val_loss: 3.4747 - val_RMSE: 0.2061
# Epoch 131/200
# 4/4 [==============================] - 0s 26ms/step - loss: 3.4539 - RMSE: 0.1934 - val_loss: 3.4695 - val_RMSE: 0.2061
# Epoch 132/200
# 4/4 [==============================] - 0s 17ms/step - loss: 3.4487 - RMSE: 0.1910 - val_loss: 3.4641 - val_RMSE: 0.2059
# Epoch 133/200
# 4/4 [==============================] - 0s 17ms/step - loss: 3.4436 - RMSE: 0.1872 - val_loss: 3.4588 - val_RMSE: 0.2059
# Epoch 134/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.4380 - RMSE: 0.1817 - val_loss: 3.4535 - val_RMSE: 0.2057
# Epoch 135/200
# 4/4 [==============================] - 0s 18ms/step - loss: 3.4329 - RMSE: 0.1851 - val_loss: 3.4482 - val_RMSE: 0.2056
# Epoch 136/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.4274 - RMSE: 0.1879 - val_loss: 3.4429 - val_RMSE: 0.2055
# Epoch 137/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.4222 - RMSE: 0.1863 - val_loss: 3.4377 - val_RMSE: 0.2054
# Epoch 138/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.4166 - RMSE: 0.1884 - val_loss: 3.4325 - val_RMSE: 0.2054
# Epoch 139/200
# 4/4 [==============================] - 0s 17ms/step - loss: 3.4109 - RMSE: 0.1796 - val_loss: 3.4272 - val_RMSE: 0.2052
# Epoch 140/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.4059 - RMSE: 0.1817 - val_loss: 3.4220 - val_RMSE: 0.2052
# Epoch 141/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.4011 - RMSE: 0.1884 - val_loss: 3.4167 - val_RMSE: 0.2051
# Epoch 142/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.3956 - RMSE: 0.1808 - val_loss: 3.4116 - val_RMSE: 0.2051
# Epoch 143/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3898 - RMSE: 0.1748 - val_loss: 3.4065 - val_RMSE: 0.2051
# Epoch 144/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.3849 - RMSE: 0.1775 - val_loss: 3.4012 - val_RMSE: 0.2049
# Epoch 145/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3801 - RMSE: 0.1871 - val_loss: 3.3959 - val_RMSE: 0.2047
# Epoch 146/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3741 - RMSE: 0.1742 - val_loss: 3.3908 - val_RMSE: 0.2047
# Epoch 147/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3693 - RMSE: 0.1849 - val_loss: 3.3856 - val_RMSE: 0.2045
# Epoch 148/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.3639 - RMSE: 0.1883 - val_loss: 3.3804 - val_RMSE: 0.2045
# Epoch 149/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3591 - RMSE: 0.1819 - val_loss: 3.3753 - val_RMSE: 0.2044
# Epoch 150/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3540 - RMSE: 0.1853 - val_loss: 3.3701 - val_RMSE: 0.2043
# Epoch 151/200
# 4/4 [==============================] - 0s 24ms/step - loss: 3.3481 - RMSE: 0.1907 - val_loss: 3.3650 - val_RMSE: 0.2043
# Epoch 152/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.3435 - RMSE: 0.1880 - val_loss: 3.3598 - val_RMSE: 0.2041
# Epoch 153/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.3384 - RMSE: 0.1828 - val_loss: 3.3547 - val_RMSE: 0.2040
# Epoch 154/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.3332 - RMSE: 0.1839 - val_loss: 3.3496 - val_RMSE: 0.2039
# Epoch 155/200
# 4/4 [==============================] - 0s 17ms/step - loss: 3.3278 - RMSE: 0.1824 - val_loss: 3.3444 - val_RMSE: 0.2038
# Epoch 156/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3224 - RMSE: 0.1906 - val_loss: 3.3394 - val_RMSE: 0.2038
# Epoch 157/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.3174 - RMSE: 0.1862 - val_loss: 3.3343 - val_RMSE: 0.2037
# Epoch 158/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.3126 - RMSE: 0.1838 - val_loss: 3.3293 - val_RMSE: 0.2036
# Epoch 159/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.3070 - RMSE: 0.1879 - val_loss: 3.3243 - val_RMSE: 0.2036
# Epoch 160/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.3024 - RMSE: 0.1850 - val_loss: 3.3192 - val_RMSE: 0.2035
# Epoch 161/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.2970 - RMSE: 0.1825 - val_loss: 3.3139 - val_RMSE: 0.2032
# Epoch 162/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2919 - RMSE: 0.1854 - val_loss: 3.3089 - val_RMSE: 0.2032
# Epoch 163/200
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2870 - RMSE: 0.1823 - val_loss: 3.3038 - val_RMSE: 0.2030
# Epoch 164/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.2816 - RMSE: 0.1852 - val_loss: 3.2988 - val_RMSE: 0.2029
# Epoch 165/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2768 - RMSE: 0.1834 - val_loss: 3.2937 - val_RMSE: 0.2028
# Epoch 166/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2715 - RMSE: 0.1837 - val_loss: 3.2887 - val_RMSE: 0.2027
# Epoch 167/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.2666 - RMSE: 0.1852 - val_loss: 3.2837 - val_RMSE: 0.2026
# Epoch 168/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2616 - RMSE: 0.1803 - val_loss: 3.2787 - val_RMSE: 0.2026
# Epoch 169/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.2565 - RMSE: 0.1778 - val_loss: 3.2737 - val_RMSE: 0.2025
# Epoch 170/200
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2514 - RMSE: 0.1782 - val_loss: 3.2688 - val_RMSE: 0.2025
# Epoch 171/200
# 4/4 [==============================] - 0s 29ms/step - loss: 3.2465 - RMSE: 0.1832 - val_loss: 3.2638 - val_RMSE: 0.2023
# Epoch 172/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.2412 - RMSE: 0.1771 - val_loss: 3.2588 - val_RMSE: 0.2022
# Epoch 173/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.2361 - RMSE: 0.1849 - val_loss: 3.2538 - val_RMSE: 0.2021
# Epoch 174/200
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2315 - RMSE: 0.1789 - val_loss: 3.2489 - val_RMSE: 0.2020
# Epoch 175/200
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2262 - RMSE: 0.1752 - val_loss: 3.2439 - val_RMSE: 0.2019
# Epoch 176/200
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2214 - RMSE: 0.1819 - val_loss: 3.2389 - val_RMSE: 0.2018
# Epoch 177/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.2163 - RMSE: 0.1810 - val_loss: 3.2340 - val_RMSE: 0.2017
# Epoch 178/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2113 - RMSE: 0.1753 - val_loss: 3.2291 - val_RMSE: 0.2016
# Epoch 179/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.2064 - RMSE: 0.1794 - val_loss: 3.2241 - val_RMSE: 0.2015
# Epoch 180/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2012 - RMSE: 0.1825 - val_loss: 3.2192 - val_RMSE: 0.2015
# Epoch 181/200
# 4/4 [==============================] - 0s 17ms/step - loss: 3.1960 - RMSE: 0.1839 - val_loss: 3.2144 - val_RMSE: 0.2015
# Epoch 182/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.1916 - RMSE: 0.1771 - val_loss: 3.2094 - val_RMSE: 0.2013
# Epoch 183/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1865 - RMSE: 0.1750 - val_loss: 3.2046 - val_RMSE: 0.2012
# Epoch 184/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.1817 - RMSE: 0.1808 - val_loss: 3.1998 - val_RMSE: 0.2012
# Epoch 185/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1769 - RMSE: 0.1818 - val_loss: 3.1949 - val_RMSE: 0.2011
# Epoch 186/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1717 - RMSE: 0.1855 - val_loss: 3.1900 - val_RMSE: 0.2010
# Epoch 187/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1669 - RMSE: 0.1740 - val_loss: 3.1851 - val_RMSE: 0.2009
# Epoch 188/200
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1620 - RMSE: 0.1785 - val_loss: 3.1803 - val_RMSE: 0.2008
# Epoch 189/200
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1573 - RMSE: 0.1834 - val_loss: 3.1755 - val_RMSE: 0.2007
# Epoch 190/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1523 - RMSE: 0.1789 - val_loss: 3.1707 - val_RMSE: 0.2007
# Epoch 191/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.1475 - RMSE: 0.1780 - val_loss: 3.1659 - val_RMSE: 0.2007
# Epoch 192/200
# 4/4 [==============================] - 0s 17ms/step - loss: 3.1425 - RMSE: 0.1799 - val_loss: 3.1611 - val_RMSE: 0.2006
# Epoch 193/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.1379 - RMSE: 0.1803 - val_loss: 3.1564 - val_RMSE: 0.2006
# Epoch 194/200
# 4/4 [==============================] - 0s 18ms/step - loss: 3.1329 - RMSE: 0.1744 - val_loss: 3.1515 - val_RMSE: 0.2004
# Epoch 195/200
# 4/4 [==============================] - 0s 17ms/step - loss: 3.1281 - RMSE: 0.1827 - val_loss: 3.1467 - val_RMSE: 0.2003
# Epoch 196/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.1233 - RMSE: 0.1782 - val_loss: 3.1420 - val_RMSE: 0.2003
# Epoch 197/200
# 4/4 [==============================] - 0s 17ms/step - loss: 3.1184 - RMSE: 0.1779 - val_loss: 3.1371 - val_RMSE: 0.2001
# Epoch 198/200
# 4/4 [==============================] - 0s 16ms/step - loss: 3.1135 - RMSE: 0.1770 - val_loss: 3.1324 - val_RMSE: 0.2001
# Epoch 199/200
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1087 - RMSE: 0.1751 - val_loss: 3.1276 - val_RMSE: 0.2000
# Epoch 200/200
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1033 - RMSE: 0.1669 - val_loss: 3.1236 - val_RMSE: 0.2006

# %%
# Plot RMSE
import matplotlib.pyplot as plt
plt.plot(result.history['RMSE'], label = 'Train RMSE')
plt.plot(result.history['val_RMSE'], label = 'Test RMSE')
plt.xlabel('epoch')
plt.ylabel('RMSE')
plt.legend()
plt.show()

# %%
user = list(set(vod_train.user_id.values))
result_1 = pd.DataFrame()
for id in user:
    temp = model.predict([np.array([id] * vod_score.vod_id.nunique()), vod_score.vod_id.unique()])
    predict_1 = pd.DataFrame(temp.ravel().tolist(), vod_score.vod_id.unique()).reset_index()
    predict_1.columns = ['vod_id', 'value']
    predict_1 = predict_1.sort_values(by = 'value', ascending=False).vod_id.values
    predict_1 = pd.DataFrame([predict_1])
    result_1 = pd.concat([result_1, predict_1])

result_1.index = user
result_1 = result_1.apply(lambda x : x.tolist(), axis = 1)
result_1 = result_1.reset_index()
result_1.columns = ['user_id', 'vod_id']
result_1
# Out:
# 23/23 [==============================] - 0s 3ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 4ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
#     user_id                                             vod_id
# 0         0  [1156, 410, 111, 1166, 1233, 848, 2402, 112, 8...
# 1         1  [1156, 111, 410, 1166, 1233, 992, 848, 112, 24...
# 2         2  [1156, 111, 410, 992, 1166, 1233, 954, 848, 88...
# 3         3  [1156, 111, 410, 1166, 1233, 848, 112, 884, 24...
# 4         4  [1156, 111, 410, 1166, 1086, 1233, 992, 884, 7...
# ..      ...                                                ...
# 70       70  [1156, 111, 410, 1233, 1166, 848, 112, 2092, 9...
# 71       71  [1156, 111, 410, 1166, 1233, 112, 884, 848, 24...
# 72       72  [1156, 111, 410, 848, 1166, 1233, 112, 2402, 9...
# 73       73  [1156, 111, 410, 1166, 1233, 848, 112, 992, 24...
# 74       74  [1156, 111, 410, 1166, 1233, 848, 2402, 315, 9...
#
# [75 rows x 2 columns]

# %%
TVpro_kids = vod_id[(vod_id['category'] == 'TV프로그램') | (vod_id['category'] == '키즈')].vod_id.unique().tolist()
movie = vod_id[vod_id['category'] == '영화'].vod_id.values.tolist()

# 시청한 영화는 추천에서 뺴고,
# 시청한 TV프로그램이나 키즈는 추천에 포함시킨다.

k = 10
result_2 = pd.DataFrame()
for i in user:
    li = []
    watched_list = vod_train[vod_train.user_id == i].vod_id.values.tolist() # 해당 유저가 시청한 프로그램
    rec_list = result_1[result_1['user_id'] == i]['vod_id'].tolist()[0]
    for x in rec_list:
        if len(li) == k:
            break

        if x not in watched_list:
            li.append(x)
        elif x in watched_list and x in TVpro_kids:
            li.append(x)
        elif x in watched_list and x in movie:
            continue

    result_2 = pd.concat([result_2, pd.DataFrame(li).T], axis = 0)


result_2.index = user
result_2 = result_2.apply(lambda x : x.tolist(), axis = 1)
result_2 = result_2.reset_index()
result_2.columns = ['user_id', 'vod_id']
result_2
# Out:
#     user_id                                             vod_id
# 0         0  [1156, 410, 111, 1166, 1233, 848, 2402, 112, 8...
# 1         1  [1156, 111, 410, 1166, 1233, 992, 848, 112, 24...
# 2         2  [1156, 111, 410, 992, 1166, 1233, 954, 848, 88...
# 3         3  [1156, 111, 410, 1166, 1233, 848, 112, 884, 24...
# 4         4  [1156, 111, 410, 1166, 1086, 1233, 992, 884, 7...
# ..      ...                                                ...
# 70       70  [1156, 111, 410, 1233, 1166, 848, 112, 2092, 9...
# 71       71  [1156, 111, 410, 1166, 1233, 112, 884, 848, 24...
# 72       72  [1156, 111, 410, 848, 1166, 1233, 112, 2402, 9...
# 73       73  [1156, 111, 410, 1166, 1233, 848, 112, 992, 24...
# 74       74  [1156, 111, 410, 1166, 1233, 848, 2402, 315, 9...
#
# [75 rows x 2 columns]

# %%
testdata = vod_test.groupby('user_id')['vod_id'].unique().reset_index()
testdata
# Out:
#     user_id                                             vod_id
# 0         0                                             [3314]
# 1         1                                              [456]
# 2         2                              [2038, 849, 887, 976]
# 3         3                                        [747, 2712]
# 4         4                 [2040, 1070, 3203, 4117, 778, 303]
# ..      ...                                                ...
# 70       70                               [835, 256, 542, 580]
# 71       71  [107, 784, 2283, 2466, 2230, 2908, 1362, 2273,...
# 72       72                                       [2341, 4380]
# 73       73                                             [1981]
# 74       74                                   [743, 341, 2537]
#
# [75 rows x 2 columns]

# %%
# precision@15
def precision_k(testdata, recommended_data, K = k):
    merge_df = pd.merge(testdata, recommended_data, on='user_id', how = 'left', suffixes=('_actual', '_rec'))
    merge_df = merge_df.dropna()
    precision_value = 0
    for i in range(merge_df.shape[0]):
        temp = len(set(merge_df.iloc[i,1]).intersection(set(merge_df.iloc[i, 2]))) / K
        precision_value += temp
        
    return precision_value / merge_df.shape[0]

precision_k(testdata, result_2)
# Out:
# 0.005333333333333334

# %%
result_1.to_csv('../data/result_1.csv', index = 0)
testdata.to_csv('../data/testdata.csv', index = 0)
