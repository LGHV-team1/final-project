# %%
import pandas as pd
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
vod_08 = pd.read_csv('/content/drive/MyDrive/VOD Project/준호/데이터스쿨3차_2308월/데이터스쿨_3차_VOD_2308.csv', encoding = 'cp949', sep = '\t')
vod_08.head(1)
# Out:
#       subsr                     asset_nm     ct_cl genre_of_ct_cl  use_tms  \
# 0  65941000  (HD)그것이알고싶다 1361회(23/07/22)  TV 시사/교양             기타     4800
#
#                                                 SMRY ACTR_DISP disp_rtm  \
# 0  살인자의 자백 그리고 아크말의 고백. 방대한 수사기록과 당시 아크말의 진술을 토대로...       김상중     1:20
#
#           strt_dt
# 0  20230812163507

# %%
vod_08.isnull().sum()
# Out:
# subsr             0
# asset_nm          0
# ct_cl             0
# genre_of_ct_cl    0
# use_tms           0
# SMRY              3
# ACTR_DISP         3
# disp_rtm          0
# strt_dt           0
# dtype: int64

# %%
from pandas._libs.tslibs.offsets import Hour
def preprocessing(df):
  # 예고편 제거
  df = df[~df['asset_nm'].str.contains('예고')]

  # 제목에 괄호와 그 안의 내용 제거
  df['asset_nm'] = df['asset_nm'].str.replace(r'\([^)]*\)', '', regex=True)

  # use_tms 분 단위로 변경
  df['use_tms'] = round(df['use_tms'] / 60, 1)

  # disp_rtm 문자열을 분 단위로 변경
  def convert_runtime(runtime_str):
    hours = int(runtime_str.split(':')[0])
    minutes = int(runtime_str.split(':')[1])
    total_minutes = hours * 60 + minutes
    return total_minutes

  df['disp_rtm'] = df['disp_rtm'].apply(convert_runtime)

  return df

# %%
df = preprocessing(vod_08)
df.head()
# Out:
#       subsr           asset_nm     ct_cl genre_of_ct_cl  use_tms  \
# 0  65941000      그것이알고싶다 1361회  TV 시사/교양             기타     80.0
# 1  66873000      그것이알고싶다 1361회  TV 시사/교양             기타     80.0
# 2  66873000      그것이알고싶다 1361회  TV 시사/교양             기타     12.0
# 3  61689000      그것이알고싶다 1361회  TV 시사/교양             기타     80.0
# 4  61619000  꼬리에꼬리를무는그날이야기 37회  TV 시사/교양             기타     69.7
#
#                                                 SMRY    ACTR_DISP  disp_rtm  \
# 0  살인자의 자백 그리고 아크말의 고백. 방대한 수사기록과 당시 아크말의 진술을 토대로...          김상중        80
# 1  살인자의 자백 그리고 아크말의 고백. 방대한 수사기록과 당시 아크말의 진술을 토대로...          김상중        80
# 2  살인자의 자백 그리고 아크말의 고백. 방대한 수사기록과 당시 아크말의 진술을 토대로...          김상중        80
# 3  살인자의 자백 그리고 아크말의 고백. 방대한 수사기록과 당시 아크말의 진술을 토대로...          김상중        80
# 4  살인범의 미토콘드리아 - 2006 냉동고 살인사건. 2006년 7월 23일, 서울 ...  장도연,장현성,장성규        73
#
#           strt_dt
# 0  20230812163507
# 1  20230816205227
# 2  20230829194727
# 3  20230813130609
# 4  20230804092737

# %%
df = df.dropna()

# %%
df.head(3)
# Out:
#       subsr       asset_nm     ct_cl genre_of_ct_cl  use_tms  \
# 0  65941000  그것이알고싶다 1361회  TV 시사/교양             기타     80.0
# 1  66873000  그것이알고싶다 1361회  TV 시사/교양             기타     80.0
# 2  66873000  그것이알고싶다 1361회  TV 시사/교양             기타     12.0
#
#                                                 SMRY ACTR_DISP  disp_rtm  \
# 0  살인자의 자백 그리고 아크말의 고백. 방대한 수사기록과 당시 아크말의 진술을 토대로...       김상중        80
# 1  살인자의 자백 그리고 아크말의 고백. 방대한 수사기록과 당시 아크말의 진술을 토대로...       김상중        80
# 2  살인자의 자백 그리고 아크말의 고백. 방대한 수사기록과 당시 아크말의 진술을 토대로...       김상중        80
#
#           strt_dt
# 0  20230812163507
# 1  20230816205227
# 2  20230829194727

# %%
df1 = df[['asset_nm', 'ct_cl', 'genre_of_ct_cl', 'SMRY', 'ACTR_DISP', 'disp_rtm']].drop_duplicates().reset_index(drop = True)
df1.head()
# Out:
#             asset_nm     ct_cl genre_of_ct_cl  \
# 0      그것이알고싶다 1361회  TV 시사/교양             기타
# 1  꼬리에꼬리를무는그날이야기 37회  TV 시사/교양             기타
# 2  꼬리에꼬리를무는그날이야기 61회  TV 시사/교양             기타
# 3         인간극장 3338회  TV 시사/교양             기타
# 4  꼬리에꼬리를무는그날이야기 89회  TV 시사/교양             기타
#
#                                                 SMRY    ACTR_DISP  disp_rtm
# 0  살인자의 자백 그리고 아크말의 고백. 방대한 수사기록과 당시 아크말의 진술을 토대로...          김상중        80
# 1  살인범의 미토콘드리아 - 2006 냉동고 살인사건. 2006년 7월 23일, 서울 ...  장도연,장현성,장성규        73
# 2                             협박범의 편지 - 4천만 대국민 인질극.  장도연,장현성,장성규        73
# 3  [스리랑카 명선 스님 인연 4부] 스리랑카 절을 찾은 명선 스님. 스리랑카에서는 스...        명선 스님        32
# 4  어느 날 내가 사라졌다 - 그 여자의 살인 시나리오. 2010년 6월, 부산에 있는...  장도연,장현성,장성규        78

# %%
df2 = pd.DataFrame(df.groupby(['subsr','asset_nm'])['use_tms'].sum()).reset_index()
df2.head()
# Out:
#       subsr       asset_nm  use_tms
# 0  59879000  소방서 옆 경찰서 05회      2.4
# 1  59879000  소방서 옆 경찰서 06회     22.1
# 2  59879000     신성한 이혼 01회     12.6
# 3  59879000     신성한 이혼 02회     16.8
# 4  59879000     신성한 이혼 03회      4.3

# %%
# 유저별 asset_nm 본 시간 합친 데이터프레임
df3 = df2.merge(df1, on = 'asset_nm', how = 'left')
df3 = df3[(df3['disp_rtm'] != 0) & (df3['use_tms'] != 0)]
df3
# Out:
#          subsr       asset_nm  use_tms  ct_cl genre_of_ct_cl  \
# 0     59879000  소방서 옆 경찰서 05회      2.4  TV드라마             기타
# 1     59879000  소방서 옆 경찰서 06회     22.1  TV드라마             기타
# 2     59879000     신성한 이혼 01회     12.6  TV드라마             기타
# 3     59879000     신성한 이혼 02회     16.8  TV드라마             기타
# 4     59879000     신성한 이혼 03회      4.3  TV드라마             기타
# ...        ...            ...      ...    ...            ...
# 3344  67117000     모범택시 2 02회     65.0  TV드라마             기타
# 3345  67117000     모범택시 2 03회     63.0  TV드라마             기타
# 3348  67122000          범죄도시3      0.8     영화        액션/어드벤쳐
# 3349  67122000          브릭 맨션      0.9     영화        액션/어드벤쳐
# 3350  67126000    존 윅 3: 파라벨룸      0.6     영화        액션/어드벤쳐
#
#                                                    SMRY  \
# 0     범죄 모의 일당에 지원하며, 언더커버 작전을 시작하는 호개. 그런데 이 놈들, 단순...
# 1     컨테이너 함바집 화재 현장에서 발견된 의문의 불에 탄 시체! 순조롭게 진행된 경찰 ...
# 2     독특한 이력을 자랑하는 이혼 전문 변호사 신성한에게 외도 스캔들로 곤혹을 겪는 유명...
# 3           의외의 인물로부터 사건 해결의 열쇠를 찾은 성한은 재판장에서 승부수를 던진다.
# 4     말 못할 고부갈등으로 성한을 찾아온 애란. 한편, 달갑지 않은 손님이 성한 앞에 등...
# ...                                                 ...
# 3344  실종된 동재를 찾기 위해 베트남으로 향한 도기, 감금되고 만다. 도기와의 연락이 끊...
# 3345  다시 모인 도기와 무지개 운수 멤버들. 내가 죽으면 우리 아들한테 안 가는 게 맞지...
# 3348  서비스 해지 시까지 시청 가능. 대체불가 괴물형사 마석도, 서울 광수대로 발탁! 베...
# 3349  불의의 교통사고로 세상을 떠난 배우 폴 워커의 마지막 액션. 허를 찌르는 설정과 통...
# 3350  전설이 된 킬러 존 윅. 룰을 어긴 죄로 그에게 현상금 1,400만 불이 붙고, 세...
#
#                                               ACTR_DISP  disp_rtm
# 0                                           김래원,손호준,공승연        69
# 1                                           김래원,손호준,공승연        59
# 2                                       조승우,한혜진,김성균,정문성        64
# 3                                       조승우,한혜진,김성균,정문성        62
# 4                                       조승우,한혜진,김성균,정문성        63
# ...                                                 ...       ...
# 3344                            이제훈,김의성,표예진,장혁진,배유람,신재하        65
# 3345                            이제훈,김의성,표예진,장혁진,배유람,신재하        63
# 3348                                   마동석,이준혁,아오키 무네타카       105
# 3349  폴 워커,데이빗 벨,르자,고치 보이,카탈리나 데니스,아이샤 잇사,카를로 로타,안드레...        90
# 3350  키아누 리브스,할리 베리,로렌스 피쉬번,이안 맥쉐인,안젤리카 휴스턴,아시아 케이트 ...       131
#
# [3161 rows x 8 columns]

# %%
df3['watched'] = df3['use_tms'] / df3['disp_rtm']
df3['watched'] = df3['watched'].apply(lambda x : 1 if x >= 0.1 else 0)
df3
# Out:
#          subsr       asset_nm  use_tms  ct_cl genre_of_ct_cl  \
# 0     59879000  소방서 옆 경찰서 05회      2.4  TV드라마             기타
# 1     59879000  소방서 옆 경찰서 06회     22.1  TV드라마             기타
# 2     59879000     신성한 이혼 01회     12.6  TV드라마             기타
# 3     59879000     신성한 이혼 02회     16.8  TV드라마             기타
# 4     59879000     신성한 이혼 03회      4.3  TV드라마             기타
# ...        ...            ...      ...    ...            ...
# 3344  67117000     모범택시 2 02회     65.0  TV드라마             기타
# 3345  67117000     모범택시 2 03회     63.0  TV드라마             기타
# 3348  67122000          범죄도시3      0.8     영화        액션/어드벤쳐
# 3349  67122000          브릭 맨션      0.9     영화        액션/어드벤쳐
# 3350  67126000    존 윅 3: 파라벨룸      0.6     영화        액션/어드벤쳐
#
#                                                    SMRY  \
# 0     범죄 모의 일당에 지원하며, 언더커버 작전을 시작하는 호개. 그런데 이 놈들, 단순...
# 1     컨테이너 함바집 화재 현장에서 발견된 의문의 불에 탄 시체! 순조롭게 진행된 경찰 ...
# 2     독특한 이력을 자랑하는 이혼 전문 변호사 신성한에게 외도 스캔들로 곤혹을 겪는 유명...
# 3           의외의 인물로부터 사건 해결의 열쇠를 찾은 성한은 재판장에서 승부수를 던진다.
# 4     말 못할 고부갈등으로 성한을 찾아온 애란. 한편, 달갑지 않은 손님이 성한 앞에 등...
# ...                                                 ...
# 3344  실종된 동재를 찾기 위해 베트남으로 향한 도기, 감금되고 만다. 도기와의 연락이 끊...
# 3345  다시 모인 도기와 무지개 운수 멤버들. 내가 죽으면 우리 아들한테 안 가는 게 맞지...
# 3348  서비스 해지 시까지 시청 가능. 대체불가 괴물형사 마석도, 서울 광수대로 발탁! 베...
# 3349  불의의 교통사고로 세상을 떠난 배우 폴 워커의 마지막 액션. 허를 찌르는 설정과 통...
# 3350  전설이 된 킬러 존 윅. 룰을 어긴 죄로 그에게 현상금 1,400만 불이 붙고, 세...
#
#                                               ACTR_DISP  disp_rtm  watched
# 0                                           김래원,손호준,공승연        69        0
# 1                                           김래원,손호준,공승연        59        1
# 2                                       조승우,한혜진,김성균,정문성        64        1
# 3                                       조승우,한혜진,김성균,정문성        62        1
# 4                                       조승우,한혜진,김성균,정문성        63        0
# ...                                                 ...       ...      ...
# 3344                            이제훈,김의성,표예진,장혁진,배유람,신재하        65        1
# 3345                            이제훈,김의성,표예진,장혁진,배유람,신재하        63        1
# 3348                                   마동석,이준혁,아오키 무네타카       105        0
# 3349  폴 워커,데이빗 벨,르자,고치 보이,카탈리나 데니스,아이샤 잇사,카를로 로타,안드레...        90        0
# 3350  키아누 리브스,할리 베리,로렌스 피쉬번,이안 맥쉐인,안젤리카 휴스턴,아시아 케이트 ...       131        0
#
# [3161 rows x 9 columns]

# %%
df11 = df1.copy()

df11['asset_nm'] = df11['asset_nm'].str.replace(r'\d+회', '', regex = True)
df11['asset_nm'] = df11['asset_nm'].apply(lambda x : x.rstrip())
df11['asset_nm'] = df11['asset_nm'].apply(lambda x : x.rstrip('.'))
df11.head()
# Out:
#         asset_nm     ct_cl genre_of_ct_cl  \
# 0        그것이알고싶다  TV 시사/교양             기타
# 1  꼬리에꼬리를무는그날이야기  TV 시사/교양             기타
# 2  꼬리에꼬리를무는그날이야기  TV 시사/교양             기타
# 3           인간극장  TV 시사/교양             기타
# 4  꼬리에꼬리를무는그날이야기  TV 시사/교양             기타
#
#                                                 SMRY    ACTR_DISP  disp_rtm
# 0  살인자의 자백 그리고 아크말의 고백. 방대한 수사기록과 당시 아크말의 진술을 토대로...          김상중        80
# 1  살인범의 미토콘드리아 - 2006 냉동고 살인사건. 2006년 7월 23일, 서울 ...  장도연,장현성,장성규        73
# 2                             협박범의 편지 - 4천만 대국민 인질극.  장도연,장현성,장성규        73
# 3  [스리랑카 명선 스님 인연 4부] 스리랑카 절을 찾은 명선 스님. 스리랑카에서는 스...        명선 스님        32
# 4  어느 날 내가 사라졌다 - 그 여자의 살인 시나리오. 2010년 6월, 부산에 있는...  장도연,장현성,장성규        78

# %%
df3['series_nm'] = df3['asset_nm'].str.replace(r'\d+회', '', regex = True)
df3['series_nm'] = df3['series_nm'].apply(lambda x : x.rstrip())
df3['series_nm'] = df3['series_nm'].apply(lambda x : x.rstrip('.'))
df3
# Out:
#          subsr       asset_nm  use_tms  ct_cl genre_of_ct_cl  \
# 0     59879000  소방서 옆 경찰서 05회      2.4  TV드라마             기타
# 1     59879000  소방서 옆 경찰서 06회     22.1  TV드라마             기타
# 2     59879000     신성한 이혼 01회     12.6  TV드라마             기타
# 3     59879000     신성한 이혼 02회     16.8  TV드라마             기타
# 4     59879000     신성한 이혼 03회      4.3  TV드라마             기타
# ...        ...            ...      ...    ...            ...
# 3344  67117000     모범택시 2 02회     65.0  TV드라마             기타
# 3345  67117000     모범택시 2 03회     63.0  TV드라마             기타
# 3348  67122000          범죄도시3      0.8     영화        액션/어드벤쳐
# 3349  67122000          브릭 맨션      0.9     영화        액션/어드벤쳐
# 3350  67126000    존 윅 3: 파라벨룸      0.6     영화        액션/어드벤쳐
#
#                                                    SMRY  \
# 0     범죄 모의 일당에 지원하며, 언더커버 작전을 시작하는 호개. 그런데 이 놈들, 단순...
# 1     컨테이너 함바집 화재 현장에서 발견된 의문의 불에 탄 시체! 순조롭게 진행된 경찰 ...
# 2     독특한 이력을 자랑하는 이혼 전문 변호사 신성한에게 외도 스캔들로 곤혹을 겪는 유명...
# 3           의외의 인물로부터 사건 해결의 열쇠를 찾은 성한은 재판장에서 승부수를 던진다.
# 4     말 못할 고부갈등으로 성한을 찾아온 애란. 한편, 달갑지 않은 손님이 성한 앞에 등...
# ...                                                 ...
# 3344  실종된 동재를 찾기 위해 베트남으로 향한 도기, 감금되고 만다. 도기와의 연락이 끊...
# 3345  다시 모인 도기와 무지개 운수 멤버들. 내가 죽으면 우리 아들한테 안 가는 게 맞지...
# 3348  서비스 해지 시까지 시청 가능. 대체불가 괴물형사 마석도, 서울 광수대로 발탁! 베...
# 3349  불의의 교통사고로 세상을 떠난 배우 폴 워커의 마지막 액션. 허를 찌르는 설정과 통...
# 3350  전설이 된 킬러 존 윅. 룰을 어긴 죄로 그에게 현상금 1,400만 불이 붙고, 세...
#
#                                               ACTR_DISP  disp_rtm  watched  \
# 0                                           김래원,손호준,공승연        69        0
# 1                                           김래원,손호준,공승연        59        1
# 2                                       조승우,한혜진,김성균,정문성        64        1
# 3                                       조승우,한혜진,김성균,정문성        62        1
# 4                                       조승우,한혜진,김성균,정문성        63        0
# ...                                                 ...       ...      ...
# 3344                            이제훈,김의성,표예진,장혁진,배유람,신재하        65        1
# 3345                            이제훈,김의성,표예진,장혁진,배유람,신재하        63        1
# 3348                                   마동석,이준혁,아오키 무네타카       105        0
# 3349  폴 워커,데이빗 벨,르자,고치 보이,카탈리나 데니스,아이샤 잇사,카를로 로타,안드레...        90        0
# 3350  키아누 리브스,할리 베리,로렌스 피쉬번,이안 맥쉐인,안젤리카 휴스턴,아시아 케이트 ...       131        0
#
#         series_nm
# 0       소방서 옆 경찰서
# 1       소방서 옆 경찰서
# 2          신성한 이혼
# 3          신성한 이혼
# 4          신성한 이혼
# ...           ...
# 3344       모범택시 2
# 3345       모범택시 2
# 3348        범죄도시3
# 3349        브릭 맨션
# 3350  존 윅 3: 파라벨룸
#
# [3161 rows x 10 columns]

# %%
df33 = df3[['subsr', 'series_nm', 'ct_cl',	'genre_of_ct_cl','SMRY', 'ACTR_DISP',	'watched']].copy()
df33.head()
# Out:
#       subsr  series_nm  ct_cl genre_of_ct_cl  \
# 0  59879000  소방서 옆 경찰서  TV드라마             기타
# 1  59879000  소방서 옆 경찰서  TV드라마             기타
# 2  59879000     신성한 이혼  TV드라마             기타
# 3  59879000     신성한 이혼  TV드라마             기타
# 4  59879000     신성한 이혼  TV드라마             기타
#
#                                                 SMRY        ACTR_DISP  watched
# 0  범죄 모의 일당에 지원하며, 언더커버 작전을 시작하는 호개. 그런데 이 놈들, 단순...      김래원,손호준,공승연        0
# 1  컨테이너 함바집 화재 현장에서 발견된 의문의 불에 탄 시체! 순조롭게 진행된 경찰 ...      김래원,손호준,공승연        1
# 2  독특한 이력을 자랑하는 이혼 전문 변호사 신성한에게 외도 스캔들로 곤혹을 겪는 유명...  조승우,한혜진,김성균,정문성        1
# 3        의외의 인물로부터 사건 해결의 열쇠를 찾은 성한은 재판장에서 승부수를 던진다.  조승우,한혜진,김성균,정문성        1
# 4  말 못할 고부갈등으로 성한을 찾아온 애란. 한편, 달갑지 않은 손님이 성한 앞에 등...  조승우,한혜진,김성균,정문성        0

# %%
df4 = df33.groupby(['subsr', 'series_nm'])['watched'].sum().reset_index()
df4
# Out:
#          subsr     series_nm  watched
# 0     59879000     소방서 옆 경찰서        1
# 1     59879000        신성한 이혼        7
# 2     59900000  2022 역사저널 그날        1
# 3     59900000           마파도        1
# 4     59900000           멍뭉이        0
# ...        ...           ...      ...
# 1301  67107000   존 윅 3: 파라벨룸        1
# 1302  67117000        모범택시 2        2
# 1303  67122000         범죄도시3        0
# 1304  67122000         브릭 맨션        0
# 1305  67126000   존 윅 3: 파라벨룸        0
#
# [1306 rows x 3 columns]

# %%
df5 = pd.DataFrame(df11['asset_nm'].value_counts().reset_index())
df5.columns = ['series_nm', 'watched_all']
df5
# Out:
#          series_nm  watched_all
# 0            천고결진            44
# 1          금이야 옥이야           41
# 2    꼬리에꼬리를무는그날이야기           40
# 3           장야 2             38
# 4           TV동물농장           37
# ..             ...          ...
# 716  코펠리아 호텔의 매춘부들            1
# 717          장미빛인생            1
# 718         경마장가는길            1
# 719            세뇨라            1
# 720       이파라파냐무냐무            1
#
# [721 rows x 2 columns]

# %%
df6 = df4.merge(df5, on = 'series_nm', how = 'left')
df6
# Out:
#          subsr     series_nm  watched  watched_all
# 0     59879000     소방서 옆 경찰서        1           11
# 1     59879000        신성한 이혼        7           12
# 2     59900000  2022 역사저널 그날        1            3
# 3     59900000           마파도        1            1
# 4     59900000           멍뭉이        0            2
# ...        ...           ...      ...          ...
# 1301  67107000   존 윅 3: 파라벨룸        1            1
# 1302  67117000        모범택시 2        2            7
# 1303  67122000         범죄도시3        0            2
# 1304  67122000         브릭 맨션        0            1
# 1305  67126000   존 윅 3: 파라벨룸        0            1
#
# [1306 rows x 4 columns]

# %%
df7 = df6.groupby(['subsr'])['watched'].sum().reset_index()
df7.columns = ['subsr', 'watched_cnt']
df7
# Out:
#         subsr  watched_cnt
# 0    59879000            8
# 1    59900000            5
# 2    59921000            2
# 3    59930000            7
# 4    59933000            5
# ..        ...          ...
# 303  67106000            1
# 304  67107000            2
# 305  67117000            2
# 306  67122000            0
# 307  67126000            0
#
# [308 rows x 2 columns]

# %%
df8 = df6.merge(df7, on = 'subsr', how = 'left')
df8 = df8[df8['watched_cnt'] != 0].reset_index(drop = True)
df8
# Out:
#          subsr     series_nm  watched  watched_all  watched_cnt
# 0     59879000     소방서 옆 경찰서        1           11            8
# 1     59879000        신성한 이혼        7           12            8
# 2     59900000  2022 역사저널 그날        1            3            5
# 3     59900000           마파도        1            1            5
# 4     59900000           멍뭉이        0            2            5
# ...        ...           ...      ...          ...          ...
# 1255  67107000         고창 2부        0            1            2
# 1256  67107000    전라남도 여수 2부        0            1            2
# 1257  67107000           마크맨        1            1            2
# 1258  67107000   존 윅 3: 파라벨룸        1            1            2
# 1259  67117000        모범택시 2        2            7            2
#
# [1260 rows x 5 columns]

# %%
import numpy as np
def scoring(df):
  N = df['watched_all']
  L = df['watched_cnt']
  n = df['watched']
  lam = np.log(2) / 2
  w1 = 1 - np.exp(-1 * lam * N)
  data = pd.DataFrame([N, L]).T
  def custom_weight(data):
    if data['watched_cnt'] < data['watched_all']:
      return data['watched_all'] / data['watched_cnt']
    else:
      return 1

  w2 = data.apply(custom_weight, axis = 1)

  score = (n / N) * w1 * w2

  return score

# %%
df8['score'] = scoring(df8)
df8
# Out:
#          subsr     series_nm  watched  watched_all  watched_cnt     score
# 0     59879000     소방서 옆 경찰서        1           11            8  0.122238
# 1     59879000        신성한 이혼        7           12            8  0.861328
# 2     59900000  2022 역사저널 그날        1            3            5  0.215482
# 3     59900000           마파도        1            1            5  0.292893
# 4     59900000           멍뭉이        0            2            5  0.000000
# ...        ...           ...      ...          ...          ...       ...
# 1255  67107000         고창 2부        0            1            2  0.000000
# 1256  67107000    전라남도 여수 2부        0            1            2  0.000000
# 1257  67107000           마크맨        1            1            2  0.292893
# 1258  67107000   존 윅 3: 파라벨룸        1            1            2  0.292893
# 1259  67117000        모범택시 2        2            7            2  0.911612
#
# [1260 rows x 6 columns]

# %%
final_df = df8[['subsr', 'series_nm', 'score']]
final_df = final_df.merge(df3[['series_nm','ct_cl', 'genre_of_ct_cl']].drop_duplicates(), on = 'series_nm', how = 'inner')
final_df.columns = ['userid', 'program', 'score', 'main_cat', 'sub_cat']
final_df = final_df.sort_values(by = 'userid').reset_index(drop = True)
final_df
# Out:
#         userid      program     score main_cat  sub_cat
# 0     59879000    소방서 옆 경찰서  0.122238    TV드라마       기타
# 1     59879000       신성한 이혼  0.861328    TV드라마       기타
# 2     59900000   초대: 스와핑 데이  0.292893       영화       멜로
# 3     59900000      후궁-제왕의첩  0.292893       영화       멜로
# 4     59900000        범죄도시3  0.250000       영화  액션/어드벤쳐
# ...        ...          ...       ...      ...      ...
# 1257  67107000        고창 2부  0.000000     우리동네    연예/오락
# 1258  67107000          마크맨  0.292893       영화  액션/어드벤쳐
# 1259  67107000        고창 1부  0.000000     우리동네    연예/오락
# 1260  67107000   전라남도 여수 2부  0.000000     우리동네    연예/오락
# 1261  67117000       모범택시 2  0.911612    TV드라마       기타
#
# [1262 rows x 5 columns]

# %%
final_df.to_csv('./final_df.csv')

# %%
final_df
# Out:
#         userid      program     score main_cat  sub_cat
# 0     59879000    소방서 옆 경찰서  0.122238    TV드라마       기타
# 1     59879000       신성한 이혼  0.861328    TV드라마       기타
# 2     59900000   초대: 스와핑 데이  0.292893       영화       멜로
# 3     59900000      후궁-제왕의첩  0.292893       영화       멜로
# 4     59900000        범죄도시3  0.250000       영화  액션/어드벤쳐
# ...        ...          ...       ...      ...      ...
# 1257  67107000        고창 2부  0.000000     우리동네    연예/오락
# 1258  67107000          마크맨  0.292893       영화  액션/어드벤쳐
# 1259  67107000        고창 1부  0.000000     우리동네    연예/오락
# 1260  67107000   전라남도 여수 2부  0.000000     우리동네    연예/오락
# 1261  67117000       모범택시 2  0.911612    TV드라마       기타
#
# [1262 rows x 5 columns]
